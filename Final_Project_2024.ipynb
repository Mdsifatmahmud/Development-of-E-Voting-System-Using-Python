# %%
leader = []
for i in range(1, 6):
    leader_name = input("Enter your leader name :")
    leader.append(leader_name)
    n = len(leader)
    if n < 5 :
        print("You have been successfully registerd")
    else :
        print("Maximum candidate have been enrolled")




voter = []
number = int(input("Enter total number of voters, who want to cast their vote :"))
for i in range(1,number + 1):
    voter_id = int(input("Enter voter id number :"))
    voter.append(voter_id)

leader_1_votes = 0
leader_2_votes = 0
leader_3_votes = 0
leader_4_votes = 0
leader_5_votes = 0

max = 0

num_of_voter = len(voter)


while True :
    if voter ==[]:
        print("Voting session is over")
        max = leader_1_votes
        if leader_2_votes > max:
            max = leader_2_votes
            percent = (leader_2_votes/num_of_voter)*100
            print(leader[1],"has won","with",percent,"% votes")
            break
        elif leader_3_votes > max:
            max = leader_3_votes
            percent = (leader_3_votes/num_of_voter)*100
            print(leader[2],"has won","with",percent,"% votes")
            break
        elif leader_4_votes > max:
            max = leader_4_votes
            percent = (leader_4_votes/num_of_voter)*100
            print(leader[3],"has won","with",percent,"% votes")
            break
        elif leader_5_votes > max:
            max = leader_5_votes
            percent = (leader_5_votes/num_of_voter)*100
            print(leader[4],"has won","with",percent,"% votes")
            break
        else :
            percent = (leader_1_votes/num_of_voter)*100
            print(leader[0],"has won","with",percent,"% votes")
            break


    else :
         voter_id = int(input("Enter your voter-id no :"))
         if voter_id in voter:
            print("You are a voter ")
            voter.remove(voter_id)
            print("========================================================\n")
            print("Here are the list of leader name :")
            print(" 1.leader-1 : ",leader[0],
                  "\n 2.leader-2 :",leader[1],
                  "\n 3.leader-3 :",leader[2],
                  "\n 4.leader-4 :",leader[3],
                  "\n 5.leader-5 :",leader[4])

            vote = int(input("Cast your vote for leader 1 or leader2 or leader3 or leader4 or leader5  :\n"
             " Write only sr. no of leader(like 1 or 2 ) :\n"))
            print("===========================================================\n")

            if vote == 1:
               leader_1_votes +=1
               print("Thank you for casting your vote ")
            elif vote == 2:
               leader_2_votes +=1
               print("Thank you for casting your vote")
            elif vote == 3:
               leader_3_votes +=1
               print("Thank you for casting your vote")
            elif vote == 4:
               leader_4_votes +=1
               print("Thank you for casting your vote")
            elif vote == 5:
               leader_5_votes +=1
               print("Thank you for casting your vote")
            else :
                print("Leader is not found \n PLease enter correct leader number")


         else :

               print("You have already voted or invalid voter id  ")


print("Total Number of Votes Recieved:")

print(leader[0],": ", leader_1_votes)
print(leader[1],": ", leader_2_votes)
print(leader[2],": ", leader_3_votes)
print(leader[3],": ", leader_4_votes)
print(leader[4],": ", leader_5_votes)
# Out:
# Enter your leader name :nafi
# You have been successfully registerd
# Enter your leader name :rafi
# You have been successfully registerd
# Enter your leader name :hadi
# You have been successfully registerd
# Enter your leader name :niloy
# You have been successfully registerd
# Enter your leader name :asif
# Maximum candidate have been enrolled
# Enter total number of voters, who want to cast their vote :5
# Enter voter id number :1
# Enter voter id number :2
# Enter voter id number :3
# Enter voter id number :4
# Enter voter id number :5
# Enter your voter-id no :5
# You are a voter
# ========================================================
#
# Here are the list of leader name :
#  1.leader-1 :  nafi
#  2.leader-2 : rafi
#  3.leader-3 : hadi
#  4.leader-4 : niloy
#  5.leader-5 : asif
# Cast your vote for leader 1 or leader2 or leader3 or leader4 or leader5  :
#  Write only sr. no of leader(like 1 or 2 ) :
# 3
# ===========================================================
#
# Thank you for casting your vote
# Enter your voter-id no :5
# You have already voted or invalid voter id
# Enter your voter-id no :3
# You are a voter
# ========================================================
#
# Here are the list of leader name :
#  1.leader-1 :  nafi
#  2.leader-2 : rafi
#  3.leader-3 : hadi
#  4.leader-4 : niloy
#  5.leader-5 : asif
# Cast your vote for leader 1 or leader2 or leader3 or leader4 or leader5  :
#  Write only sr. no of leader(like 1 or 2 ) :
# 1
# ===========================================================
#
# Thank you for casting your vote
# Enter your voter-id no :2
# You are a voter
# ========================================================
#
# Here are the list of leader name :
#  1.leader-1 :  nafi
#  2.leader-2 : rafi
#  3.leader-3 : hadi
#  4.leader-4 : niloy
#  5.leader-5 : asif
# Cast your vote for leader 1 or leader2 or leader3 or leader4 or leader5  :
#  Write only sr. no of leader(like 1 or 2 ) :
# 2
# ===========================================================
#
# Thank you for casting your vote
# Enter your voter-id no :2
# You have already voted or invalid voter id
# Enter your voter-id no :4
# You are a voter
# ========================================================
#
# Here are the list of leader name :
#  1.leader-1 :  nafi
#  2.leader-2 : rafi
#  3.leader-3 : hadi
#  4.leader-4 : niloy
#  5.leader-5 : asif
# Cast your vote for leader 1 or leader2 or leader3 or leader4 or leader5  :
#  Write only sr. no of leader(like 1 or 2 ) :
# 1
# ===========================================================
#
# Thank you for casting your vote
# Enter your voter-id no :6
# You have already voted or invalid voter id
# Enter your voter-id no :2
# You have already voted or invalid voter id
# Enter your voter-id no :7
# You have already voted or invalid voter id
# Enter your voter-id no :1
# You are a voter
# ========================================================
#
# Here are the list of leader name :
#  1.leader-1 :  nafi
#  2.leader-2 : rafi
#  3.leader-3 : hadi
#  4.leader-4 : niloy
#  5.leader-5 : asif
# Cast your vote for leader 1 or leader2 or leader3 or leader4 or leader5  :
#  Write only sr. no of leader(like 1 or 2 ) :
# 8
# ===========================================================
#
# Leader is not found
#  PLease enter correct leader number
# Voting session is over
# nafi has won with 40.0 % votes
# Total Number of Votes Recieved:
# nafi :  2
# rafi :  1
# hadi :  1
# niloy :  0
# asif :  0
